# %%
import json
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-dfb9ba8b3e0c> in <module>
#       5 file_path = "project/static/layers/temp_0.js"
#       6 dataFrame = pd.read_excel(
# ----> 7     "project/static/excel/" + str(214) + ".xlsx", engine="openpyxl"
#       8 )
#       9 dump_path = "project/static/layers/oneline_features.js"
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
 
file_path = "project/static/layers/temp_0.js"
dataFrame = pd.read_excel(
    "./static/excel/" + str(214) + ".xlsx", engine="openpyxl"
)
dump_path = "project/static/layers/oneline_features.js"
print(dataFrame.head)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-56739dc162ee> in <module>
#       1 file_path = "project/static/layers/temp_0.js"
#       2 dataFrame = pd.read_excel(
# ----> 3     "/static/excel/" + str(214) + ".xlsx", engine="openpyxl"
#       4 )
#       5 dump_path = "project/static/layers/oneline_features.js"
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...
